# %%
import numpy as np
import tensorflow as tf
# Out:
# WARNING:tensorflow:From C:\Users\tobit\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
mnist = tf.keras.datasets.mnist
(train_data, train_labels), (eval_data, eval_labels) = mnist.load_data()

# %%
train_data = train_data.reshape(train_data.shape[0], 28, 28, 1)  # Returns np.array
eval_data = eval_data.reshape(eval_data.shape[0], 28, 28, 1)  # Returns np.array

num_class = 10

train_labels = tf.keras.utils.to_categorical(train_labels, num_class)
eval_labels = tf.keras.utils.to_categorical(eval_labels, num_class)

# %%
model = tf.keras.Sequential()

model.add(
    tf.keras.layers.Conv2D(32, kernel_size=(3, 3), activation=tf.nn.relu, input_shape=(28, 28, 1), padding='same'))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.Conv2D(32, kernel_size=(3, 3), activation=tf.nn.relu, padding='same'))
model.add(tf.keras.layers.BatchNormalization())

model.add(tf.keras.layers.MaxPool2D((2, 2)))
model.add(tf.keras.layers.Dropout(0.20))

model.add(tf.keras.layers.Conv2D(64, (3, 3), activation=tf.nn.relu, padding='same'))
model.add(tf.keras.layers.BatchNormalization())
# model.add(tf.keras.layers.Conv2D(64, (3, 3), activation=tf.nn.relu, padding='same'))
# model.add(tf.keras.layers.BatchNormalization())

model.add(tf.keras.layers.MaxPool2D(pool_size=(2, 2)))
model.add(tf.keras.layers.Dropout(0.30))

model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(200, activation=tf.nn.relu))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.Dropout(0.50))

model.add(tf.keras.layers.Dense(10, activation=tf.nn.softmax, name="output"))

model.compile(loss=tf.keras.losses.categorical_crossentropy,
              optimizer=tf.keras.optimizers.Adam(),
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_16 (Conv2D)          (None, 28, 28, 32)        320
#
#  batch_normalization_19 (Ba  (None, 28, 28, 32)        128
#  tchNormalization)
#
#  conv2d_17 (Conv2D)          (None, 28, 28, 32)        9248
#
#  batch_normalization_20 (Ba  (None, 28, 28, 32)        128
#  tchNormalization)
#
#  max_pooling2d_10 (MaxPooli  (None, 14, 14, 32)        0
#  ng2D)
#
#  dropout_13 (Dropout)        (None, 14, 14, 32)        0
#
#  conv2d_18 (Conv2D)          (None, 14, 14, 64)        18496
#
#  batch_normalization_21 (Ba  (None, 14, 14, 64)        256
#  tchNormalization)
#
#  max_pooling2d_11 (MaxPooli  (None, 7, 7, 64)          0
#  ng2D)
#
#  dropout_14 (Dropout)        (None, 7, 7, 64)          0
#
#  flatten_4 (Flatten)         (None, 3136)              0
#
#  dense_3 (Dense)             (None, 200)               627400
#
#  batch_normalization_22 (Ba  (None, 200)               800
#  tchNormalization)
#
#  dropout_15 (Dropout)        (None, 200)               0
#
#  output (Dense)              (None, 10)                2010
#
# =================================================================
# Total params: 658786 (2.51 MB)
# Trainable params: 658130 (2.51 MB)
# Non-trainable params: 656 (2.56 KB)
# _________________________________________________________________

# %%
model.fit(train_data, train_labels, epochs=2)
# Out:
# Epoch 1/2
# 1875/1875 [==============================] - 20s 10ms/step - loss: 0.1669 - accuracy: 0.9489
# Epoch 2/2
# 1875/1875 [==============================] - 18s 9ms/step - loss: 0.0753 - accuracy: 0.9768

# %%
model.evaluate(eval_data, eval_labels, verbose=2)
# Out:
# 313/313 - 2s - loss: 0.0399 - accuracy: 0.9864 - 2s/epoch - 5ms/step
# [0.039944637566804886, 0.9864000082015991]

# %%
import matplotlib.pyplot as plt

# %%
#make a list of the layers we care about (convolution and pooling)
layer_outputs = [layer.output for layer in model.layers[:]]
layer_outputs_filtered = [layer for layer in layer_outputs if 'dropout' not in layer.name and 'flatten' not in layer.name and 'dense' not in layer.name]
activation_model = tf.keras.Model(inputs=model.input, outputs=layer_outputs_filtered[:-2])
activations = activation_model.predict(eval_data[0:])
# Out:
# 313/313 [==============================] - 3s 10ms/step

# %%
def visualize_sample(list):
    layer_names = []
    for layer in list[:-2]:
        layer_names.append(layer.name) # Names of the layers, so you can have them as part of your plot
        
        images_per_row = 16
    for layer_name, layer_activation in zip(layer_names, activations): # Displays the feature maps
        n_features = layer_activation.shape[-1] # Number of features in the feature map
        size = layer_activation.shape[1] #The feature map has shape (1, size, size, n_features).
        n_cols = n_features // images_per_row # Tiles the activation channels in this matrix
        display_grid = np.zeros((size * n_cols, images_per_row * size))
        for col in range(n_cols): # Tiles each filter into a big horizontal grid
            for row in range(images_per_row):
                channel_image = layer_activation[0,
                                                 :, :,
                                                 col * images_per_row + row]
                channel_image -= channel_image.mean() # Post-processes the feature to make it visually palatable
                channel_image /= channel_image.std()
                channel_image *= 64
                channel_image += 128
                channel_image = np.clip(channel_image, 0, 255).astype('uint8')
                display_grid[col * size : (col + 1) * size, # Displays the grid
                             row * size : (row + 1) * size] = channel_image
        scale = 1. / size
        plt.figure(figsize=(scale * display_grid.shape[1],
                            scale * display_grid.shape[0]))
        plt.title(layer_name)
        plt.grid(False)
        plt.imshow(display_grid, aspect='auto', cmap='viridis')

# %%
visualize_sample(layer_outputs_filtered)

# %%
#make a list of the layers we care about (convolution and pooling)
activations = activation_model.predict(eval_data[2:])
# Out:
# 313/313 [==============================] - 2s 7ms/step

# %%
visualize_sample(layer_outputs_filtered)
# Out:
# C:\Users\tobit\AppData\Local\Temp\ipykernel_38856\2285998845.py:18: RuntimeWarning: invalid value encountered in divide
#   channel_image /= channel_image.std()
# C:\Users\tobit\AppData\Local\Temp\ipykernel_38856\2285998845.py:21: RuntimeWarning: invalid value encountered in cast
#   channel_image = np.clip(channel_image, 0, 255).astype('uint8')
